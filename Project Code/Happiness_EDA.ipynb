# %%
import pandas as pd

# %%
df = pd.read_csv('data_rank.csv')

# %%
df.head()
# Out:
#    Year      Country  Happiness Rank  Happiness Score  \
# 0  2015  Switzerland               1            7.587
# 1  2015      Iceland               2            7.561
# 2  2015      Denmark               3            7.527
# 3  2015       Norway               4            7.522
# 4  2015       Canada               5            7.427
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity
# 0                        0.41978     0.29678
# 1                        0.14145     0.43630
# 2                        0.48357     0.34139
# ...

# %%
df.shape
# Out:
# (1367, 10)

# %%
df.describe()
# Out:
#               Year  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# count  1367.000000     1367.000000      1367.000000               1367.000000
# mean   2018.903438       76.577908         5.441086                  3.690225
# std       2.561006       44.088602         1.117909                  3.996117
# min    2015.000000        1.000000         1.859000                  0.000000
# 25%    2017.000000       38.500000         4.599500                  0.877137
# 50%    2019.000000       76.000000         5.440000                  1.299470
# 75%    2021.000000      114.000000         6.256300                  8.360500
# max    2023.000000      158.000000         7.842000                 11.660000
#
#             Family  Health (Life Expectancy)      Freedom  \
# count  1367.000000               1366.000000  1367.000000
# mean      0.973053                  0.621001     0.543280
# std       0.301305                  0.200911     0.221468
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1367 entries, 0 to 1366
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Year                           1367 non-null   int64
#  1   Country                        1367 non-null   object
#  2   Happiness Rank                 1367 non-null   int64
#  3   Happiness Score                1367 non-null   float64
#  4   Economy (GDP per Capita)       1367 non-null   float64
#  5   Family                         1367 non-null   float64
#  6   Health (Life Expectancy)       1366 non-null   float64
#  7   Freedom                        1367 non-null   float64
#  8   Trust (Government Corruption)  1366 non-null   float64
#  9   Generosity                     1367 non-null   float64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 106.9+ KB

# %%
#Check for nulls
df.isnull().sum()
# Out:
# Year                             0
# Country                          0
# Happiness Rank                   0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         1
# Freedom                          0
# Trust (Government Corruption)    1
# Generosity                       0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Year                             0
# Country                          0
# Happiness Rank                   0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# dtype: int64

# %%
df.describe()
# Out:
#               Year  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# count  1365.000000     1365.000000      1365.000000               1365.000000
# mean   2018.901099       76.602930         5.440500                  3.687711
# std       2.560363       44.090124         1.118053                  3.996495
# min    2015.000000        1.000000         1.859000                  0.000000
# 25%    2017.000000       39.000000         4.596000                  0.876160
# 50%    2019.000000       76.000000         5.440000                  1.296000
# 75%    2021.000000      114.000000         6.255000                  8.360000
# max    2023.000000      158.000000         7.842000                 11.660000
#
#             Family  Health (Life Expectancy)      Freedom  \
# count  1365.000000               1365.000000  1365.000000
# mean      0.973281                  0.620965     0.543359
# std       0.301463                  0.200981     0.221482
# ...

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Year, Country, Happiness Rank, Happiness Score, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity]
# Index: []

# %%
df.to_csv("data_rank_cleaning.csv", sep=",", index=False)
